# %% [markdown]
# **[GxGP](https://github.com/squillero/gxgp)** — *A no-nonsense GP in pure Python*

# %%
import operator

# %%
from gxgp import Node

tree = Node(operator.mul, [Node(operator.add, [Node(10),
                                               Node('x')]),
                           Node(2)])
tree.draw()

# %%
tree(x=11)
# Out:
# 42

# %%
tree()  # Error: missing 'x'
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 tree()  # Error: missing 'x'
#
# File ~/Repos/gxgp/gxgp/node.py:56, in Node.__call__(self, **kwargs)
#      55 def __call__(self, **kwargs):
# ---> 56     return self._func(*[c(**kwargs) for c in self._successors], **kwargs)
#
# File ~/Repos/gxgp/gxgp/node.py:56, in Node.__call__(self, **kwargs)
#      55 def __call__(self, **kwargs):
# ---> 56     return self._func(*[c(**kwargs) for c in self._successors], **kwargs)
#
# File ~/Repos/gxgp/gxgp/node.py:56, in Node.__call__(self, **kwargs)
#      55 def __call__(self, **kwargs):
# ---> 56     return self._func(*[c(**kwargs) for c in self._successors], **kwargs)
#
# TypeError: <lambda>() missing 1 required keyword-only argument: 'x'

# %%
tree2 = Node(lambda a, b, c, d, e: (a + b * c - d) / e,
             [Node('x'), Node('y'), Node(3), Node('z'), Node(2)])
tree2.draw()

# %%
# Explicit keyword arguments (unused arguments are ignored)
tree2(x=1, y=2, z=3, foo=42)
# Out:
# 2.0

# %%
# Unpacking a dictionary
vars = {'x': 1, 'y': 2, 'z': 3, 'foo': 42}
tree2(**vars)
# Out:
# 2.0
